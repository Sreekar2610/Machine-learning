# %%
import os
import requests
import re
import time
import random
import cv2
import numpy as np
from io import BytesIO

def create_directory(directory):
    """Create a directory if it doesn't exist."""
    if not os.path.exists(directory):
        os.makedirs(directory)
        print(f"Directory '{directory}' created.")
    else:
        print(f"Directory '{directory}' already exists.")
    return directory

def get_bing_image_urls(query, count=20):
    """Get image URLs from Bing Image Search."""
    print(f"Searching for '{query}' images on Bing...")
    
    # Format the search query for Bing
    search_url = f"https://www.bing.com/images/search?q={query.replace(' ', '+')}&form=HDRSC2&first=1"
    
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Accept-Language': 'en-US,en;q=0.5',
        'Connection': 'keep-alive',
        'Upgrade-Insecure-Requests': '1',
        'Cache-Control': 'max-age=0'
    }
    
    try:
        response = requests.get(search_url, headers=headers)
        response.raise_for_status()
        
        # Regular expression to find image URLs in the HTML
        img_pattern = r'murl&quot;:&quot;(https?://[^&]+)&quot;'
        matches = re.findall(img_pattern, response.text)
        
        # Clean up URLs (remove escaped characters)
        image_urls = []
        for url in matches:
            clean_url = url.replace('\\', '')
            if clean_url not in image_urls:
                image_urls.append(clean_url)
                if len(image_urls) >= count:
                    break
        
        print(f"Found {len(image_urls)} image URLs.")
        return image_urls
    
    except Exception as e:
        print(f"Error searching Bing: {e}")
        return []

def is_valid_image(image_data):
    """Check if the image data can be properly read by OpenCV."""
    try:
        # Convert image data to numpy array
        nparr = np.frombuffer(image_data, np.uint8)
        
        # Decode the image
        img = cv2.imdecode(nparr, cv2.IMREAD_COLOR)
        
        # Check if image is valid and not empty
        if img is None or img.size == 0:
            return False
            
        # Try converting to grayscale (this will catch many common issues)
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        
        # Additional checks can be added here if needed
        return True
    except Exception as e:
        print(f"Image validation error: {e}")
        return False

def download_image(url, directory, file_name):
    """Download an image from the given URL, validate it can be used by OpenCV, and save it to the specified directory."""
    try:
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Referer': 'https://www.bing.com/images',
        }
        
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()
        
        # Get the image data
        image_data = response.content
        
        # Validate that OpenCV can read this image
        if not is_valid_image(image_data):
            print(f"Skipping invalid image from {url}")
            return False
        
        # Determine the file extension based on content type
        content_type = response.headers.get('Content-Type', '')
        if 'jpeg' in content_type or 'jpg' in content_type:
            ext = 'jpg'
        elif 'png' in content_type:
            ext = 'png'
        elif 'webp' in content_type:
            ext = 'webp'
        elif 'gif' in content_type:
            ext = 'gif'
        else:
            # If content type is not clear, try to get extension from URL
            if '.jpg' in url or '.jpeg' in url:
                ext = 'jpg'
            elif '.png' in url:
                ext = 'png'
            elif '.webp' in url:
                ext = 'webp'
            elif '.gif' in url:
                ext = 'gif'
            else:
                ext = 'jpg'  # Default to jpg
        
        # Full path with file name
        file_path = os.path.join(directory, f"{file_name}.{ext}")
        
        # Save the image
        with open(file_path, 'wb') as f:
            f.write(image_data)
        
        # Double-check the saved file
        try:
            img = cv2.imread(file_path)
            if img is None or img.size == 0:
                print(f"Warning: Saved file {file_path} cannot be read by OpenCV. Removing it.")
                os.remove(file_path)
                return False
            # Try converting to grayscale as a final validation
            cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        except Exception as e:
            print(f"Post-save validation failed for {file_path}: {e}. Removing file.")
            if os.path.exists(file_path):
                os.remove(file_path)
            return False
            
        print(f"Downloaded and validated: {file_name}.{ext}")
        return True
    
    except Exception as e:
        print(f"Error downloading {url}: {e}")
        return False

def download_hardik_pandya_images(count=20, output_dir='hardik_pandya_images', 
                                 queries=None):
    """Main function to download Hardik Pandya images that can be processed by OpenCV"""
    if queries is None:
        queries = [
            'Hardik Pandya cricket portrait',
            'Hardik Pandya face clear',
            'Hardik Pandya close up',
            'Hardik Pandya headshot',
            'Hardik Pandya India team portrait'
        ]
    
    # Create the output directory
    output_dir = create_directory(output_dir)
    
    # Get image URLs for each query
    all_image_urls = []
    
    # Get more images than needed since some might fail validation
    extra_factor = 2  # Get 2x the needed count since some will fail validation
    adjusted_count = count * extra_factor
    
    images_per_query = adjusted_count // len(queries)
    remaining = adjusted_count % len(queries)
    
    for i, query in enumerate(queries):
        query_count = images_per_query + (1 if i < remaining else 0)
        if query_count > 0:
            urls = get_bing_image_urls(query, query_count)
            all_image_urls.extend(urls)
    
    # Shuffle to get a mix of different types of images
    random.shuffle(all_image_urls)
    
    # Download and validate images
    print(f"\nDownloading and validating images...")
    
    successful_downloads = 0
    i = 0
    
    while successful_downloads < count and i < len(all_image_urls):
        url = all_image_urls[i]
        file_name = f"hardik_pandya_{successful_downloads+1}"
        success = download_image(url, output_dir, file_name)
        
        if success:
            successful_downloads += 1
            print(f"Progress: {successful_downloads}/{count} valid images downloaded")
            
        # Small delay to avoid being blocked
        time.sleep(0.5)
        i += 1
        
        if i >= len(all_image_urls) and successful_downloads < count:
            print(f"Ran out of image URLs. Only found {successful_downloads} valid images out of {count} requested.")
            break
    
    print(f"\nDownload complete! {successful_downloads} validated images saved to '{output_dir}'.")
    return output_dir

# %%
download_hardik_pandya_images(
    count=200, 
    output_dir='hardik_images',
    queries=['Hardik Pandya batting', 'Hardik Pandya FAMILY', 'Hardik Pandya teammates']
)
# Out:
# Directory 'hardik_images' created.
# Searching for 'Hardik Pandya batting' images on Bing...
# Found 83 image URLs.
# Searching for 'Hardik Pandya FAMILY' images on Bing...
# Found 90 image URLs.
# Searching for 'Hardik Pandya teammates' images on Bing...
# Found 30 image URLs.
#
# Downloading and validating images...
# Downloaded and validated: hardik_pandya_1.webp
# Progress: 1/200 valid images downloaded
# Error downloading https://editorial01.shutterstock.com/preview-440/10322624di/24b28cd5/Shutterstock_10322624di.jpg: 404 Client Error: Not Found for url: https://editorial01.shutterstock.com/preview-440/10322624di/24b28cd5/Shutterstock_10322624di.jpg
# Downloaded and validated: hardik_pandya_2.jpg
# Progress: 2/200 valid images downloaded
# Downloaded and validated: hardik_pandya_3.jpg
# Progress: 3/200 valid images downloaded
# Downloaded and validated: hardik_pandya_4.jpg
# Progress: 4/200 valid images downloaded
# Downloaded and validated: hardik_pandya_5.webp
# Progress: 5/200 valid images downloaded
# Downloaded and validated: hardik_pandya_6.png
# Progress: 6/200 valid images downloaded
# Downloaded and validated: hardik_pandya_7.jpg
# Progress: 7/200 valid images downloaded
# Downloaded and validated: hardik_pandya_8.png
# Progress: 8/200 valid images downloaded
# Downloaded and validated: hardik_pandya_9.jpg
# Progress: 9/200 valid images downloaded
# Downloaded and validated: hardik_pandya_10.jpg
# Progress: 10/200 valid images downloaded
# Downloaded and validated: hardik_pandya_11.jpg
# Progress: 11/200 valid images downloaded
# Downloaded and validated: hardik_pandya_12.jpg
# Progress: 12/200 valid images downloaded
# Downloaded and validated: hardik_pandya_13.jpg
# Progress: 13/200 valid images downloaded
# Downloaded and validated: hardik_pandya_14.jpg
# Progress: 14/200 valid images downloaded
# Downloaded and validated: hardik_pandya_15.jpg
# Progress: 15/200 valid images downloaded
# Downloaded and validated: hardik_pandya_16.jpg
# Progress: 16/200 valid images downloaded
# Downloaded and validated: hardik_pandya_17.jpg
# Progress: 17/200 valid images downloaded
# Downloaded and validated: hardik_pandya_18.jpg
# Progress: 18/200 valid images downloaded
# Downloaded and validated: hardik_pandya_19.jpg
# Progress: 19/200 valid images downloaded
# Downloaded and validated: hardik_pandya_20.jpg
# Progress: 20/200 valid images downloaded
# Downloaded and validated: hardik_pandya_21.jpg
# Progress: 21/200 valid images downloaded
# Downloaded and validated: hardik_pandya_22.jpg
# Progress: 22/200 valid images downloaded
# Downloaded and validated: hardik_pandya_23.jpg
# Progress: 23/200 valid images downloaded
# Downloaded and validated: hardik_pandya_24.jpg
# Progress: 24/200 valid images downloaded
# Downloaded and validated: hardik_pandya_25.jpg
# Progress: 25/200 valid images downloaded
# Downloaded and validated: hardik_pandya_26.jpg
# Progress: 26/200 valid images downloaded
# Downloaded and validated: hardik_pandya_27.png
# Progress: 27/200 valid images downloaded
# Downloaded and validated: hardik_pandya_28.jpg
# Progress: 28/200 valid images downloaded
# Downloaded and validated: hardik_pandya_29.jpg
# Progress: 29/200 valid images downloaded
# Downloaded and validated: hardik_pandya_30.jpg
# Progress: 30/200 valid images downloaded
# Downloaded and validated: hardik_pandya_31.jpg
# Progress: 31/200 valid images downloaded
# Downloaded and validated: hardik_pandya_32.jpg
# Progress: 32/200 valid images downloaded
# Downloaded and validated: hardik_pandya_33.jpg
# Progress: 33/200 valid images downloaded
# Downloaded and validated: hardik_pandya_34.jpg
# Progress: 34/200 valid images downloaded
# Downloaded and validated: hardik_pandya_35.webp
# Progress: 35/200 valid images downloaded
# Downloaded and validated: hardik_pandya_36.jpg
# Progress: 36/200 valid images downloaded
# Downloaded and validated: hardik_pandya_37.jpg
# Progress: 37/200 valid images downloaded
# Downloaded and validated: hardik_pandya_38.jpg
# Progress: 38/200 valid images downloaded
# Downloaded and validated: hardik_pandya_39.png
# Progress: 39/200 valid images downloaded
# Downloaded and validated: hardik_pandya_40.jpg
# Progress: 40/200 valid images downloaded
# Downloaded and validated: hardik_pandya_41.jpg
# Progress: 41/200 valid images downloaded
# Downloaded and validated: hardik_pandya_42.webp
# Progress: 42/200 valid images downloaded
# Downloaded and validated: hardik_pandya_43.jpg
# Progress: 43/200 valid images downloaded
# Downloaded and validated: hardik_pandya_44.jpg
# Progress: 44/200 valid images downloaded
# Downloaded and validated: hardik_pandya_45.jpg
# Progress: 45/200 valid images downloaded
# Downloaded and validated: hardik_pandya_46.jpg
# Progress: 46/200 valid images downloaded
# Downloaded and validated: hardik_pandya_47.jpg
# Progress: 47/200 valid images downloaded
# Downloaded and validated: hardik_pandya_48.jpg
# Progress: 48/200 valid images downloaded
# Downloaded and validated: hardik_pandya_49.jpg
# Progress: 49/200 valid images downloaded
# Downloaded and validated: hardik_pandya_50.jpg
# Progress: 50/200 valid images downloaded
# Downloaded and validated: hardik_pandya_51.jpg
# Progress: 51/200 valid images downloaded
# Downloaded and validated: hardik_pandya_52.jpg
# Progress: 52/200 valid images downloaded
# Downloaded and validated: hardik_pandya_53.jpg
# Progress: 53/200 valid images downloaded
# Downloaded and validated: hardik_pandya_54.jpg
# Progress: 54/200 valid images downloaded
# Downloaded and validated: hardik_pandya_55.jpg
# Progress: 55/200 valid images downloaded
# Downloaded and validated: hardik_pandya_56.jpg
# Progress: 56/200 valid images downloaded
# Error downloading https://famousbiography.org/wp-content/uploads/2021/09/Hardik-Pandya-Father-and-Brother.jpg: HTTPSConnectionPool(host='famousbiography.org', port=443): Max retries exceeded with url: /wp-content/uploads/2021/09/Hardik-Pandya-Father-and-Brother.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001CD85F1AA10>: Failed to resolve 'famousbiography.org' ([Errno 11002] getaddrinfo failed)"))
# Downloaded and validated: hardik_pandya_57.jpg
# Progress: 57/200 valid images downloaded
# Downloaded and validated: hardik_pandya_58.jpg
# Progress: 58/200 valid images downloaded
# Downloaded and validated: hardik_pandya_59.jpg
# Progress: 59/200 valid images downloaded
# Downloaded and validated: hardik_pandya_60.jpg
# Progress: 60/200 valid images downloaded
# Downloaded and validated: hardik_pandya_61.jpg
# Progress: 61/200 valid images downloaded
# Downloaded and validated: hardik_pandya_62.jpg
# Progress: 62/200 valid images downloaded
# Downloaded and validated: hardik_pandya_63.jpg
# Progress: 63/200 valid images downloaded
# Downloaded and validated: hardik_pandya_64.jpg
# Progress: 64/200 valid images downloaded
# Downloaded and validated: hardik_pandya_65.jpg
# Progress: 65/200 valid images downloaded
# Downloaded and validated: hardik_pandya_66.jpg
# Progress: 66/200 valid images downloaded
# Downloaded and validated: hardik_pandya_67.jpg
# Progress: 67/200 valid images downloaded
# Downloaded and validated: hardik_pandya_68.jpg
# Progress: 68/200 valid images downloaded
# Downloaded and validated: hardik_pandya_69.jpg
# Progress: 69/200 valid images downloaded
# Downloaded and validated: hardik_pandya_70.jpg
# Progress: 70/200 valid images downloaded
# Downloaded and validated: hardik_pandya_71.jpg
# Progress: 71/200 valid images downloaded
# Downloaded and validated: hardik_pandya_72.jpg
# Progress: 72/200 valid images downloaded
# Downloaded and validated: hardik_pandya_73.jpg
# Progress: 73/200 valid images downloaded
# Downloaded and validated: hardik_pandya_74.jpg
# Progress: 74/200 valid images downloaded
# Downloaded and validated: hardik_pandya_75.jpg
# Progress: 75/200 valid images downloaded
# Downloaded and validated: hardik_pandya_76.jpg
# Progress: 76/200 valid images downloaded
# Downloaded and validated: hardik_pandya_77.jpg
# Progress: 77/200 valid images downloaded
# Downloaded and validated: hardik_pandya_78.jpg
# Progress: 78/200 valid images downloaded
# Downloaded and validated: hardik_pandya_79.jpg
# Progress: 79/200 valid images downloaded
# Downloaded and validated: hardik_pandya_80.jpg
# Progress: 80/200 valid images downloaded
# Downloaded and validated: hardik_pandya_81.jpg
# Progress: 81/200 valid images downloaded
# Downloaded and validated: hardik_pandya_82.jpg
# Progress: 82/200 valid images downloaded
# Downloaded and validated: hardik_pandya_83.jpg
# Progress: 83/200 valid images downloaded
# Downloaded and validated: hardik_pandya_84.jpg
# Progress: 84/200 valid images downloaded
# Downloaded and validated: hardik_pandya_85.jpg
# Progress: 85/200 valid images downloaded
# Downloaded and validated: hardik_pandya_86.webp
# Progress: 86/200 valid images downloaded
# Downloaded and validated: hardik_pandya_87.jpg
# Progress: 87/200 valid images downloaded
# Downloaded and validated: hardik_pandya_88.jpg
# Progress: 88/200 valid images downloaded
# Downloaded and validated: hardik_pandya_89.jpg
# Progress: 89/200 valid images downloaded
# Downloaded and validated: hardik_pandya_90.webp
# Progress: 90/200 valid images downloaded
# Downloaded and validated: hardik_pandya_91.jpg
# Progress: 91/200 valid images downloaded
# Downloaded and validated: hardik_pandya_92.jpg
# Progress: 92/200 valid images downloaded
# Downloaded and validated: hardik_pandya_93.jpg
# Progress: 93/200 valid images downloaded
# Downloaded and validated: hardik_pandya_94.jpg
# Progress: 94/200 valid images downloaded
# Downloaded and validated: hardik_pandya_95.jpg
# Progress: 95/200 valid images downloaded
# Downloaded and validated: hardik_pandya_96.jpg
# Progress: 96/200 valid images downloaded
# Downloaded and validated: hardik_pandya_97.png
# Progress: 97/200 valid images downloaded
# Downloaded and validated: hardik_pandya_98.jpg
# Progress: 98/200 valid images downloaded
# Downloaded and validated: hardik_pandya_99.webp
# Progress: 99/200 valid images downloaded
# Downloaded and validated: hardik_pandya_100.jpg
# Progress: 100/200 valid images downloaded
# Downloaded and validated: hardik_pandya_101.jpg
# Progress: 101/200 valid images downloaded
# Downloaded and validated: hardik_pandya_102.jpg
# Progress: 102/200 valid images downloaded
# Downloaded and validated: hardik_pandya_103.jpg
# Progress: 103/200 valid images downloaded
# Downloaded and validated: hardik_pandya_104.jpg
# Progress: 104/200 valid images downloaded
# Error downloading https://editorial01.shutterstock.com/wm-preview-1500/13364455cf/250a0175/Shutterstock_13364455cf.jpg: 404 Client Error: Not Found for url: https://editorial01.shutterstock.com/wm-preview-1500/13364455cf/250a0175/Shutterstock_13364455cf.jpg
# Downloaded and validated: hardik_pandya_105.jpg
# Progress: 105/200 valid images downloaded
# Downloaded and validated: hardik_pandya_106.jpg
# Progress: 106/200 valid images downloaded
# Downloaded and validated: hardik_pandya_107.jpg
# Progress: 107/200 valid images downloaded
# Downloaded and validated: hardik_pandya_108.webp
# Progress: 108/200 valid images downloaded
# Downloaded and validated: hardik_pandya_109.jpg
# Progress: 109/200 valid images downloaded
# Downloaded and validated: hardik_pandya_110.jpg
# Progress: 110/200 valid images downloaded
# Downloaded and validated: hardik_pandya_111.jpg
# Progress: 111/200 valid images downloaded
# Downloaded and validated: hardik_pandya_112.jpg
# Progress: 112/200 valid images downloaded
# Downloaded and validated: hardik_pandya_113.jpg
# Progress: 113/200 valid images downloaded
# Downloaded and validated: hardik_pandya_114.jpg
# Progress: 114/200 valid images downloaded
# Downloaded and validated: hardik_pandya_115.jpg
# Progress: 115/200 valid images downloaded
# Downloaded and validated: hardik_pandya_116.jpg
# Progress: 116/200 valid images downloaded
# Downloaded and validated: hardik_pandya_117.jpg
# Progress: 117/200 valid images downloaded
# Downloaded and validated: hardik_pandya_118.jpg
# Progress: 118/200 valid images downloaded
# Downloaded and validated: hardik_pandya_119.webp
# Progress: 119/200 valid images downloaded
# Downloaded and validated: hardik_pandya_120.jpg
# Progress: 120/200 valid images downloaded
# Downloaded and validated: hardik_pandya_121.jpg
# Progress: 121/200 valid images downloaded
# Downloaded and validated: hardik_pandya_122.jpg
# Progress: 122/200 valid images downloaded
# Downloaded and validated: hardik_pandya_123.jpg
# Progress: 123/200 valid images downloaded
# Downloaded and validated: hardik_pandya_124.jpg
# Progress: 124/200 valid images downloaded
# Downloaded and validated: hardik_pandya_125.jpg
# Progress: 125/200 valid images downloaded
# Downloaded and validated: hardik_pandya_126.jpg
# Progress: 126/200 valid images downloaded
# Downloaded and validated: hardik_pandya_127.jpg
# Progress: 127/200 valid images downloaded
# Downloaded and validated: hardik_pandya_128.jpg
# Progress: 128/200 valid images downloaded
# Downloaded and validated: hardik_pandya_129.jpg
# Progress: 129/200 valid images downloaded
# Downloaded and validated: hardik_pandya_130.png
# Progress: 130/200 valid images downloaded
# Downloaded and validated: hardik_pandya_131.jpg
# Progress: 131/200 valid images downloaded
# Error downloading https://editorial01.shutterstock.com/preview-440/13701581ac/1b9b7164/Shutterstock_13701581ac.jpg: 404 Client Error: Not Found for url: https://editorial01.shutterstock.com/preview-440/13701581ac/1b9b7164/Shutterstock_13701581ac.jpg
# Downloaded and validated: hardik_pandya_132.png
# Progress: 132/200 valid images downloaded
# Downloaded and validated: hardik_pandya_133.jpg
# Progress: 133/200 valid images downloaded
# Downloaded and validated: hardik_pandya_134.png
# Progress: 134/200 valid images downloaded
# Downloaded and validated: hardik_pandya_135.jpg
# Progress: 135/200 valid images downloaded
# Downloaded and validated: hardik_pandya_136.jpg
# Progress: 136/200 valid images downloaded
# Downloaded and validated: hardik_pandya_137.jpg
# Progress: 137/200 valid images downloaded
# Downloaded and validated: hardik_pandya_138.webp
# Progress: 138/200 valid images downloaded
# Downloaded and validated: hardik_pandya_139.jpg
# Progress: 139/200 valid images downloaded
# Downloaded and validated: hardik_pandya_140.jpg
# Progress: 140/200 valid images downloaded
# Downloaded and validated: hardik_pandya_141.jpg
# Progress: 141/200 valid images downloaded
# Downloaded and validated: hardik_pandya_142.png
# Progress: 142/200 valid images downloaded
# Downloaded and validated: hardik_pandya_143.jpg
# Progress: 143/200 valid images downloaded
# Downloaded and validated: hardik_pandya_144.jpg
# Progress: 144/200 valid images downloaded
# Downloaded and validated: hardik_pandya_145.jpg
# Progress: 145/200 valid images downloaded
# Downloaded and validated: hardik_pandya_146.jpg
# Progress: 146/200 valid images downloaded
# Downloaded and validated: hardik_pandya_147.jpg
# Progress: 147/200 valid images downloaded
# Downloaded and validated: hardik_pandya_148.jpg
# Progress: 148/200 valid images downloaded
# Downloaded and validated: hardik_pandya_149.png
# Progress: 149/200 valid images downloaded
# Downloaded and validated: hardik_pandya_150.jpg
# Progress: 150/200 valid images downloaded
# Downloaded and validated: hardik_pandya_151.webp
# Progress: 151/200 valid images downloaded
# Downloaded and validated: hardik_pandya_152.jpg
# Progress: 152/200 valid images downloaded
# Downloaded and validated: hardik_pandya_153.jpg
# Progress: 153/200 valid images downloaded
# Downloaded and validated: hardik_pandya_154.jpg
# Progress: 154/200 valid images downloaded
# Downloaded and validated: hardik_pandya_155.jpg
# Progress: 155/200 valid images downloaded
# Downloaded and validated: hardik_pandya_156.jpg
# Progress: 156/200 valid images downloaded
# Downloaded and validated: hardik_pandya_157.jpg
# Progress: 157/200 valid images downloaded
# Downloaded and validated: hardik_pandya_158.png
# Progress: 158/200 valid images downloaded
# Downloaded and validated: hardik_pandya_159.jpg
# Progress: 159/200 valid images downloaded
# Downloaded and validated: hardik_pandya_160.jpg
# Progress: 160/200 valid images downloaded
# Downloaded and validated: hardik_pandya_161.jpg
# Progress: 161/200 valid images downloaded
# Downloaded and validated: hardik_pandya_162.jpg
# Progress: 162/200 valid images downloaded
# Downloaded and validated: hardik_pandya_163.jpg
# Progress: 163/200 valid images downloaded
# Downloaded and validated: hardik_pandya_164.jpg
# Progress: 164/200 valid images downloaded
# Downloaded and validated: hardik_pandya_165.jpg
# Progress: 165/200 valid images downloaded
# Downloaded and validated: hardik_pandya_166.jpg
# Progress: 166/200 valid images downloaded
# Downloaded and validated: hardik_pandya_167.webp
# Progress: 167/200 valid images downloaded
# Downloaded and validated: hardik_pandya_168.jpg
# Progress: 168/200 valid images downloaded
# Downloaded and validated: hardik_pandya_169.jpg
# Progress: 169/200 valid images downloaded
# Downloaded and validated: hardik_pandya_170.jpg
# Progress: 170/200 valid images downloaded
# Downloaded and validated: hardik_pandya_171.jpg
# Progress: 171/200 valid images downloaded
# Downloaded and validated: hardik_pandya_172.jpg
# Progress: 172/200 valid images downloaded
# Downloaded and validated: hardik_pandya_173.jpg
# Progress: 173/200 valid images downloaded
# Downloaded and validated: hardik_pandya_174.webp
# Progress: 174/200 valid images downloaded
# Downloaded and validated: hardik_pandya_175.jpg
# Progress: 175/200 valid images downloaded
# Downloaded and validated: hardik_pandya_176.webp
# Progress: 176/200 valid images downloaded
# Downloaded and validated: hardik_pandya_177.jpg
# Progress: 177/200 valid images downloaded
# Downloaded and validated: hardik_pandya_178.jpg
# Progress: 178/200 valid images downloaded
# Error downloading https://editorial01.shutterstock.com/wm-preview-1500/10326064dc/35d5ddbd/Shutterstock_10326064dc.jpg: 404 Client Error: Not Found for url: https://editorial01.shutterstock.com/wm-preview-1500/10326064dc/35d5ddbd/Shutterstock_10326064dc.jpg
# Downloaded and validated: hardik_pandya_179.jpg
# Progress: 179/200 valid images downloaded
# Downloaded and validated: hardik_pandya_180.jpg
# Progress: 180/200 valid images downloaded
# Downloaded and validated: hardik_pandya_181.jpg
# Progress: 181/200 valid images downloaded
# Downloaded and validated: hardik_pandya_182.jpg
# Progress: 182/200 valid images downloaded
# Downloaded and validated: hardik_pandya_183.jpg
# Progress: 183/200 valid images downloaded
# Downloaded and validated: hardik_pandya_184.jpg
# Progress: 184/200 valid images downloaded
# Downloaded and validated: hardik_pandya_185.jpg
# Progress: 185/200 valid images downloaded
# Downloaded and validated: hardik_pandya_186.jpg
# Progress: 186/200 valid images downloaded
# Downloaded and validated: hardik_pandya_187.jpg
# Progress: 187/200 valid images downloaded
# Downloaded and validated: hardik_pandya_188.jpg
# Progress: 188/200 valid images downloaded
# Downloaded and validated: hardik_pandya_189.jpg
# Progress: 189/200 valid images downloaded
# Downloaded and validated: hardik_pandya_190.jpg
# Progress: 190/200 valid images downloaded
# Downloaded and validated: hardik_pandya_191.jpg
# Progress: 191/200 valid images downloaded
# Downloaded and validated: hardik_pandya_192.jpg
# Progress: 192/200 valid images downloaded
# Downloaded and validated: hardik_pandya_193.jpg
# Progress: 193/200 valid images downloaded
# Downloaded and validated: hardik_pandya_194.jpg
# Progress: 194/200 valid images downloaded
# Downloaded and validated: hardik_pandya_195.jpg
# Progress: 195/200 valid images downloaded
# Downloaded and validated: hardik_pandya_196.jpg
# Progress: 196/200 valid images downloaded
# Downloaded and validated: hardik_pandya_197.jpg
# Progress: 197/200 valid images downloaded
# Downloaded and validated: hardik_pandya_198.jpg
# Progress: 198/200 valid images downloaded
# Ran out of image URLs. Only found 198 valid images out of 200 requested.
#
# Download complete! 198 validated images saved to 'hardik_images'.
# 'hardik_images'
